# %%
d = {"name": "혼자 공부하는 데이터 분석"}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import json

# %%
d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
# Out:
# {"name": "혼자 공부하는 데이터 분석"}

# %%
print(type(d_str))
# Out:
# <class 'str'>

# %%
d2 = json.loads(d_str)
print(d2['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
print(type(d2))
# Out:
# <class 'dict'>

# %%
d3 = json.loads('{"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022}')
print(d3['name'])
print(d3['author'])
print(d3['year'])
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
d3 = json.loads('{"name": "혼자 공부하는 데이터 분석", "author": ["박해선", "홍길동"], "year": 2022}')
print(d3['author'][1])
# Out:
# 홍길동

# %%
d4_str = """
[
	{"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022},
	{"name": "혼자 공부하는 머신러닝+딥러닝", "author": "박해선", "year": 2020}
]
"""
d4 = json.loads(d4_str)
print(d4[0]['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
from io import StringIO
import pandas as pd
pd.read_json(StringIO(d4_str))
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
pd.DataFrame(d4)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
x_str = """
<book>
	<name> 혼자 공부하는 데이터 분석 </name>
	<author> 박해선 </author>
	<year> 2022 </year>
</book>
"""

# %%
import xml.etree.ElementTree as et
book = et.fromstring(x_str)

# %%
print(type(book))
# Out:
# <class 'xml.etree.ElementTree.Element'>

# %%
print(book.tag)
# Out:
# book

# %%
book_childs = list(book)
print(book_childs)
# Out:
# [<Element 'name' at 0x7d3736d0ae80>, <Element 'author' at 0x7d3736d0ae30>, <Element 'year' at 0x7d3736d0ade0>]

# %%
name, author, year = book_childs
print(name.text)
print(author.text)
print(year.text)
# Out:
#  혼자 공부하는 데이터 분석
#  박해선
#  2022

# %%
name = book.findtext('name')
author = book.findtext('author')
year = book.findtext('year')
print(name)
print(author)
print(year)
# Out:
#  혼자 공부하는 데이터 분석
#  박해선
#  2022

# %%
x2_str = """
<books>
	<book>
		<name> 혼자 공부하는 데이터 분석 </name>
		<author> 박해선 </author>
		<year> 2022 </year>
	</book>
	<book>
		<name> 혼자 공부하는 머신러닝+딥러닝 </name>
		<author> 박해선 </author>
		<year> 2020 </year>
	</book>
</books>
"""

# %%
books = et.fromstring(x2_str)
print(books.tag)
# Out:
# books

# %%
for book in books.findall('book'):
		name = book.findtext('name')
		author = book.findtext('author')
		year = book.findtext('year')
		print(name)
		print(author)
		print(year)
		print()
# Out:
#  혼자 공부하는 데이터 분석
#  박해선
#  2022
#
#  혼자 공부하는 머신러닝+딥러닝
#  박해선
#  2020

# %%
pd.read_xml(StringIO(x2_str))
# Out:
#                  name author  year
# 0     혼자 공부하는 데이터 분석    박해선   2022
# 1   혼자 공부하는 머신러닝+딥러닝    박해선   2020

# %%
import requests

# %%
url = "http://data4library.kr/api/loanItemSrch?format=json&authKey=83a25c999bfefe513d3c5628034375c396dc8059208db8cdedcf1d4db76d521a&startDt=2021-04-01&endDt=2022-04-30&age=20"

# %%
r = requests.get(url)

# %%
data = r.json()
print(data)
# Out:
# {'response': {'request': {'startDt': '2021-04-01', 'endDt': '2022-04-30', 'age': '20', 'pageNo': 1, 'pageSize': 200}, 'resultNum': 200, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ', 'authors': '지은이: 김초엽', 'publisher': '허블', 'publication_year': '2019', 'isbn13': '9791190090018', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429', 'loan_count': '7164'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ', 'authors': '지은이: 이미예', 'publisher': '팩토리나인', 'publication_year': '2020', 'isbn13': '9791165341909', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5
# ...

# %%
data
# Out:
# {'response': {'request': {'startDt': '2021-04-01',
#    'endDt': '2022-04-30',
#    'age': '20',
#    'pageNo': 1,
#    'pageSize': 200},
#   'resultNum': 200,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': '허블',
#      'publication_year': '2019',
#      'isbn13': '9791190090018',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429',
#      'loan_count': '7164'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ',
#      'authors': '지은이: 이미예',
#      'publisher': '팩토리나인',
#      'publication_year': '2020',
#      'isbn13': '9791165341909',
#      'addition_symbol': '03810',
#      'vol': '',
# ...

# %%
books = []
for d in data['response']['docs']:
		books.append(d['doc'])

# %%
books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': '허블',
#   'publication_year': '2019',
#   'isbn13': '9791190090018',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429',
#   'loan_count': '7164'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ',
#   'authors': '지은이: 이미예',
#   'publisher': '팩토리나인',
#   'publication_year': '2020',
#   'isbn13': '9791165341909',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051',
#   'loan_count': '6855'},
#  {'no': 3,
#   'ranking': '3',
# ...

# %%
books_df = pd.DataFrame(books)
books_df
# Out:
#       no ranking                               bookname  \
# 0      1       1            우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 1      2       2             달러구트 꿈 백화점 :주문하신 꿈은 매진입니다
# 2      3       3                     시선으로부터, :정세랑 장편소설
# 3      4       4                            아몬드손원평 장편소설
# 4      5       5                    지구에서 한아뿐 :정세랑 장편소설
# ..   ...     ...                                    ...
# 195  196     196   살면서 한 번은 짠테크 :스물일곱 김짠부의 행복한 재테크 이야기
# 196  197     197                       참을 수 없는 존재의 가벼움
# 197  198     198                     지적 대화를 위한 넓고 얕은 지식
# 198  199     199                                연애의 행방
# 199  200     200  트렌드 코리아 2021 :팬데믹 위기에 대응하는 전략은 무엇인가?
#
#                    authors publisher publication_year         isbn13  \
# 0                 지은이: 김초엽        허블             2019  9791190090018
# 1                 지은이: 이미예     팩토리나인             2020  9791165341909
# 2                 지은이: 정세랑      문학동네             2020  9788954672214
# ...

# %%
books_df.to_json('20s_best_book.json', force_ascii=False)
